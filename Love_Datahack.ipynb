# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
X_train = pd.read_csv("training_set_features.csv")
X_test = pd.read_csv("test_set_features.csv")
y_train = pd.read_csv("training_set_labels.csv")

# %%
X_train = X_train.drop(['employment_occupation', 'employment_industry', 'hhs_geo_region'],axis='columns')
cols=[ 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'census_msa']
X_train = pd.get_dummies(X_train, columns=cols)
cols=['xyz_concern', 'xyz_knowledge',
       'behavioral_antiviral_meds', 'behavioral_avoidance',
       'behavioral_face_mask', 'behavioral_wash_hands',
       'behavioral_large_gatherings', 'behavioral_outside_home',
       'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal',
       'chronic_med_condition', 'child_under_6_months', 'health_worker',
       'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk',
       'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective',
       'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'household_adults',
       'household_children']
for col in cols:
    X_train[col].fillna(X_train[col].median(), inplace = True)
X_train
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26702          26702          2.0            0.0                        0.0
# 26703          26703          1.0            2.0                        0.0
# 26704          26704          2.0            2.0                        0.0
# 26705          26705          1.0            1.0                        0.0
# 26706          26706          0.0            0.0                        0.0
#
# ...

# %%
X_test = X_test.drop(['employment_occupation', 'employment_industry', 'hhs_geo_region'],axis='columns')
cols=[ 'age_group', 'education', 'race', 'sex', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status', 'census_msa']
X_test = pd.get_dummies(X_test, columns=cols)
cols=['xyz_concern', 'xyz_knowledge',
       'behavioral_antiviral_meds', 'behavioral_avoidance',
       'behavioral_face_mask', 'behavioral_wash_hands',
       'behavioral_large_gatherings', 'behavioral_outside_home',
       'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal',
       'chronic_med_condition', 'child_under_6_months', 'health_worker',
       'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk',
       'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective',
       'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'household_adults',
       'household_children']
for col in cols:
    X_test[col].fillna(X_test[col].median(), inplace = True)
X_test
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              26707          2.0            2.0                        0.0
# 1              26708          1.0            1.0                        0.0
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 4              26711          3.0            1.0                        1.0
# ...              ...          ...            ...                        ...
# 26703          53410          1.0            1.0                        0.0
# 26704          53411          3.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
cols=['xyz_concern', 'xyz_knowledge',
       'behavioral_antiviral_meds', 'behavioral_avoidance',
       'behavioral_face_mask', 'behavioral_wash_hands',
       'behavioral_large_gatherings', 'behavioral_outside_home',
       'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal',
       'chronic_med_condition', 'child_under_6_months', 'health_worker',
       'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk',
       'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective',
       'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'household_adults',
       'household_children']
for col in cols:
    X_train[col].fillna(X_train[col].median(), inplace = True)

# %%
for col in cols:
    X_train[col].fillna(X_train[col].median(), inplace = True)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train,y_train["xyz_vaccine"])
y_test_xyz = model.predict_proba(X_test)[:, 1]

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train,y_train["seasonal_vaccine"])
y_test_seasonal = model.predict_proba(X_test)[:, 1]

# %%
respondent_id=np.arange(26707, 53415, dtype='int32')
len(y_test_xyz)
# Out:
# 26708

# %%
data = np.column_stack((respondent_id, y_test_xyz, y_test_seasonal))
submission = pd.DataFrame(data, columns=['respondent_id', 'h1n1_vaccine', 'seasonal_vaccine'])

# %%
submission
# Out:
#        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0            26707.0      0.037890          0.053560
# 1            26708.0      0.000157          0.000032
# 2            26709.0      0.929832          0.985749
# 3            26710.0      0.455789          0.996241
# 4            26711.0      0.469033          0.727708
# ...              ...           ...               ...
# 26703        53410.0      0.397189          0.831353
# 26704        53411.0      0.038122          0.004097
# 26705        53412.0      0.004420          0.012836
# 26706        53413.0      0.046001          0.763911
# 26707        53414.0      0.436187          0.794098
#
# [26708 rows x 3 columns]

# %%
submission.to_csv('Love_Datahack.csv', index=False)
